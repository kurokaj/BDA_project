import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 20)

from sklearn import preprocessing
from sklearn import model_selection 
from sklearn import metrics
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D


import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # BDA - Project work

# %% [markdown]
# ## Introduction

# %% [markdown]
# Draws on [Data Analysis Project - The case of Diabetes on Pima Indians](https://github.com/saidejp/Bayesian_Statistics_Techniques/blob/master/final_project.md)
#
# (motivation, the problem -- classification, main modiling idea, some figure...)
#
# ### Goal
#
#
# ### Workflow outline

# %% [markdown]
# ## Data

# %% [markdown]
# ### Description
# Data are derived from a study conducted by the National Institute of Diabetes and Kidney Digestive Diseases. It includes measurements of 768 adult at least 21 year old Indian Pima women, living near Phoenix.
# This dataset describes the medical records for Pima Indians
# and whether or not each patient will have an onset of diabetes within five years.
#
# Features:
# 1. preg: Number pregnancies
# 2. plas: Plasma glucose concentration
# 3. pres: Diastolic blood pressure (mm Hg)
# 4. skin: Triceps skin fold thickness (mm)
# 5. test: 2-Hour serum insulin (mu U/ml)
# 6. mass: Body mass index (weight in kg/(height in m)^2)
# 7. pedi: Diabetes pedigree function
# 8. age:  Age (years)
# 9. class: Class variable (1:tested positive for diabetes, 0: tested negative for diabetes)

# %% [markdown]
# ### Acquisition

# %%
#dataset = pd.read_csv('data/pima-indians-diabetes.csv', header=None)
#dataset.columns = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
#display(dataset)

# Allternative data set as with closer inspections the diabetes data set is rather difficult and inconsistent
    # There is also possible datasets on heart dicease and cancer
dataset2 = pd.read_csv('data/BankNote_Authentication.csv', header=None)
dataset2.columns = ['variance', 'skewness', 'kurtosis', 'entropy', 'class']
display(dataset2)
print(dataset2.isnan())
# Out:
#       variance  skewness  kurtosis   entropy  class
# 0     variance  skewness  curtosis   entropy  class
# 1       3.6216    8.6661   -2.8073  -0.44699      0
# 2       4.5459    8.1674   -2.4586   -1.4621      0
# 3        3.866   -2.6383    1.9242   0.10645      0
# 4       3.4566    9.5228   -4.0112   -3.5944      0
# ...        ...       ...       ...       ...    ...
# 1368   0.40614    1.3492   -1.4501  -0.55949      1
# 1369   -1.3887   -4.8773    6.4774   0.34179      1
# 1370   -3.7503  -13.4586   17.5932   -2.7771      1
# 1371   -3.5637   -8.3827    12.393   -1.2823      1
# 1372   -2.5419  -0.65804    2.6842    1.1952      1
#
# [1373 rows x 5 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-e97bdc7c9dc1> in <module>
#       8 dataset2.columns = ['variance', 'skewness', 'kurtosis', 'entropy', 'class']
#       9 display(dataset2)
# ...

# %% [markdown]
# ### Analysis (looks good, does not take time...)

# %% [markdown]
# #### Andrew curves

# %%
# PCA analysis

# Wanted to see if the data could be easier to separate after PCA.

pca = PCA(n_components=3)
pca_data = pca.fit_transform(dataset[['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age']].to_numpy())
datafr_pca = pd.DataFrame(pca_data) 
datafr_pca.columns = ['P1', 'P2', 'P3'] 

labels = dataset["class"].to_numpy()

# Visualize the pca
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(datafr_pca['P1'], datafr_pca['P2'], datafr_pca['P3'], c = labels, cmap = plt.cm.winter, alpha = 1) 

ax.set_xlabel('P1')
ax.set_ylabel('P2')
ax.set_zlabel('P3')

plt.show()

# %%
x = pd.plotting.andrews_curves(dataset, 'class', color=['r', 'b']) 
x.plot() 
  
plt.show()

# %% [markdown]
# Does not look very good for us, the classes are not separated...

# %% [markdown]
# #### Pair-plot

# %%
sns.pairplot(dataset, hue='class', markers=['x','+'])  

plt.show()

# %% [markdown]
# (Does not look very good for us...)

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Splitting

# %%
labels   = pd.DataFrame(dataset.loc[:, 'class'])
features = dataset.drop('class', axis=1)
X_train, X_test, y_train, y_test = model_selection.train_test_split(features.values, 
                                                                    labels.values.ravel(),
                                                                    test_size=0.3, 
                                                                    random_state=0)

# %% [markdown]
# #### Standardization

# %%
scaler = preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Model

# %% [markdown]
# More variants... variable selection looks easy...
#
# ### Logit classifier
#
# ### Priors
# Weakly informative... not sure how to select actually
#
# ### + Sensitibility (try more options...)
#
# ### Stan code

# %%
# DOES NOT WORK, JUST ILLUSTRATION
full_logit_model = """
data {
  int <lower=0> N;
  int <lower=0> J;
  vector[J] x[N];
  vector[N] y;
}

parameters {
  vector[J] beta;

}

transformed parameters {
    vector[J] eta = beta[1] + beta[2]*x[,1] + beta[3]*x[,2] + beta[4]*x[,3] + beta[5]*x[,4] + beta[6]*x[,5] + beta[7]*x[,6]+ beta[8]*x[,7]+ beta[9]*x[,8];
}

model {
  for (j in 1:J){
    beta[j] ~ normal(0, 100);
  }
    
  y ~ binomial_logit(N, eta);
}
"""

# %% [markdown]
# ## Training

# %%
# Model does not work yet
model = pystan.StanModel(model_code=full_logit_model)
fit = model.sampling(data=dataset, iter=500, chains=4)

# %%
# The data from the sampling
samples = fit.extract(permuted=True)

# For the Rhat value
print(fit)
# Out:
# Inference for Stan model: anon_model_018f747e8d0362f5b1db5b6cc8a0732a.
# 4 chains, each with iter=4000; warmup=2000; thin=1;
# post-warmup draws per chain=2000, total post-warmup draws=8000.
#
#            mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# theta[1]   0.96    0.02   0.89  -0.66   0.34    0.9    1.5   2.89   2723    1.0
# theta[2]  10.37    0.09   4.58    3.3   6.97   9.74   13.1  21.02   2403    1.0
# eta[1]    -7.96    0.07   3.49 -16.06  -9.98  -7.48  -5.38  -2.64   2682    1.0
# eta[2]    -2.15    0.02   1.12  -4.67  -2.81  -2.03  -1.35  -0.32   4035    1.0
# eta[3]     0.44    0.01   0.78   -1.0   -0.1   0.41   0.93   2.06   3235    1.0
# eta[4]     8.53    0.08   3.93   2.35   5.66    8.0  10.95  17.52   2270    1.0
# lp__       -7.1    0.02   1.03  -9.87   -7.5  -6.78  -6.36  -6.11   2504    1.0
#
# Samples were drawn using NUTS at Wed Nov 11 20:12:04 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# ...

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Convergence diagnostics
# Rhat, ess... just the stan function and a short discussion
# ### Model comparison
# LOO-CV
#
# ### Predictive assessment
# (accuracy, recall..., confusion matrix...)
# print(metrics.classification_report(y_test, y_test_predicted)))
#
# ### Sensitivity analysis
# Changing priors...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Resulting classifier
# Is it usable?
#
# ### Limitations and potential improvements
#
#
# ### Self-reflection
# What we learnt...

# %%
### References
